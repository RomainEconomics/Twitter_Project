# %% [markdown]
# A faire encore :
# - Améliorer le graph quand on a 5 topics ou moins
# - Rajouter un moyen dans l'application de pouvoir tester sur un échantillon de tweet la capacité du modele à classer correctement les tweets dans les bons topics

# %%
import csv

from wordcloud import WordCloud
from unidecode import unidecode
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import re

# Les bigrammes
from collections import Counter
from nltk.util import ngrams

from sklearn.model_selection import train_test_split

from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer

from sklearn.decomposition import LatentDirichletAllocation

from sklearn.decomposition import NMF

# Librairie pour stocker les différents modèles 
import joblib

# %%
# Importation des données
tweets = pd.read_csv('tweets_fr_clean.csv').dropna(subset=['tweet_clean'])
# Transformation de la colonne 'date' au format adéquat
tweets['date'] = pd.to_datetime(tweets['date'], infer_datetime_format=True)
# Défini l'indice avec la colonne 'date'
tweets.set_index(tweets['date'], inplace = True)

tweets.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 37196 entries, 2021-04-21 to 2021-04-18
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   date            37196 non-null  datetime64[ns]
#  1   time            37196 non-null  object
#  2   tweet           37196 non-null  object
#  3   tweet_clean     37196 non-null  object
#  4   hashtags        37196 non-null  object
#  5   likes_count     37196 non-null  int64
#  6   retweets_count  37196 non-null  int64
#  7   day             37196 non-null  int64
# dtypes: datetime64[ns](1), int64(3), object(4)
# memory usage: 2.6+ MB

# %%
X_train, X_hold = train_test_split(tweets, test_size=0.05, random_state=111)

# On conserve X_hold (le test set) dans un fichier csv
# Celui-ci nous servira essentiellement pour l'application Streamlit
# Afin de générer aléatoirement un tweet, et observer si les topics
# que le modèle trouve pour ce tweet nous semble correct

X_hold.to_csv('generate_random_tweets.csv')

# %%
# Fonction utilisée pour représenter les topics et les mots dans un tableau pandas
def display_topics(model, feature_names, no_top_words):
    topic_dict = {}
    for topic_idx, topic in enumerate(model.components_):
        topic_dict["Topic %d words" % (topic_idx)]= ['{}'.format(feature_names[i])
                        for i in topic.argsort()[:-no_top_words - 1:-1]]
        topic_dict["Topic %d weights" % (topic_idx)]= ['{:.1f}'.format(topic[i])
                        for i in topic.argsort()[:-no_top_words - 1:-1]]
    return pd.DataFrame(topic_dict)

# %%
# Réalise le LDA modèle avec un nombre de topics allant de 2 à 10,
# avec la possibilité de choisir unigram ou bigram,
# puis les modèles sont stockés, ainsi que les statistiques associées à chaque modèle

def LDA_many_topics(nrange = (1,1)):
    # the vectorizer object will be used to transform text to vector form
    # Max_df : pour supprimer les mots qui apparaissent dans plus de 90% des tweets car trop commun
    # Min_df : pour supprimer les mots qui apparaissent dans moins de 25 tweets car signal pas assez fort
    vectorizer = CountVectorizer(max_df=0.9, min_df=25, 
                                 ngram_range=nrange, token_pattern='\w+|\$[\d\.]+|\S+')
    
    # apply transformation
    tf = vectorizer.fit_transform(X_train['tweet_clean']).toarray()
    
    # tf_feature_names tells us what word each column in the matric represents
    tf_feature_names = vectorizer.get_feature_names()
    print("... tf_feature_names") 
    
    # Check if bigram or not
    if nrange == (2,2):
        # On sauvegarde les differents mots, commun à tous les modèles
        with open('models/bigram_tf_feature_names', 'w') as f:
            # create the csv writer
            writer = csv.writer(f)
            # write a row to the csv file
            writer.writerow(tf_feature_names)
            f.close()
    else:
        # On conserve le vectorizer afin de vectoriser le test set dans l'application streamlit
        joblib.dump(vectorizer, 'models/LDA_vectorizer')
        
        # On sauvegarde les differents mots, commun à tous les modèles
        with open('models/tf_feature_names', 'w') as f:
            # create the csv writer
            writer = csv.writer(f)
            # write a row to the csv file
            writer.writerow(tf_feature_names)
            f.close()
    
    
    # Création d'un header pour le dataframe qui servira à stocker les statistiques
    # associées à chaque modèles 
    my_columns = ['Topics', 'Score', 'Perplexity']
    model_stats = pd.DataFrame(columns = my_columns)
        
        
    # Réalise le LDA modèle avec un nombre de topics allant de 2 à 10, puis on stocke les modèles 
    for n_topics in range(2,11,1):
        
        model = LatentDirichletAllocation(n_components = n_topics, random_state = 0)
        model.fit(tf)
        
        # Stock les statistiques de chaque modèle
        model_stats = model_stats.append(
        pd.Series(
            [
                model.n_components,
                model.score(tf),
                model.perplexity(tf)
            ],
                 index = my_columns),
                 ignore_index=True
        )

        
        # Check if it's bigram or unigram and adjust the model name
        if nrange == (2,2):
            joblib.dump(model, f'models/bigramLDA_{n_topics}_topics')
            print(f"... bigramLDA_{n_topics}_topics")
        else:
            joblib.dump(model, f'models/LDA_{n_topics}_topics')
            print(f"... LDA_{n_topics}_topics")
            
    
    # Check if it's bigram or unigram and adjust the model score dataframe
    if nrange == (2,2):
        model_stats.to_csv('models/bigramLDA_scores', index=False, header=True)
    else:
        model_stats.to_csv('models/LDA_scores', index=False, header=True)

# %%
# Compute the LDA models, with unigram and then with bigram
LDA_many_topics()
print('...')
LDA_many_topics(nrange = (2,2))
# Out:
# ... tf_feature_names
# ... LDA_2_topics
# ... LDA_3_topics
# ... LDA_4_topics
# ... LDA_5_topics
# ... LDA_6_topics
# ... LDA_7_topics
# ... LDA_8_topics
# ... LDA_9_topics
# ... LDA_10_topics
# ...
# ... tf_feature_names
# ... bigramLDA_2_topics
# ... bigramLDA_3_topics
# ... bigramLDA_4_topics
# ... bigramLDA_5_topics
# ... bigramLDA_6_topics
# ... bigramLDA_7_topics
# ... bigramLDA_8_topics
# ... bigramLDA_9_topics
# ... bigramLDA_10_topics

# %%
pd.read_csv('models/LDA_scores')

# %%
pd.read_csv('models/bigramLDA_scores')

# %% [markdown]
# #### NMF

# %% [markdown]
# Source : https://scikit-learn.org/stable/auto_examples/applications/plot_topics_extraction_with_nmf_lda.html#sphx-glr-auto-examples-applications-plot-topics-extraction-with-nmf-lda-py

# %%
# Réalise le NMF modèle avec un nombre de topics allant de 2 à 10, puis on stocke les modèles 
# 2 méthodes de NMF sont effectués: Frobenius, puis Kullback-Leibler
    
def NMF_many_topics(option):
    # the vectorizer object will be used to transform text to vector form
    # Max_df : pour supprimer les mots qui apparaissent dans plus de 90% des tweets car trop commun
    # Min_df : pour supprimer les mots qui apparaissent dans moins de 25 tweets car signal pas assez fort
    tfidf_vectorizer = TfidfVectorizer(max_df=0.95, min_df=2,
                                   max_features=2000)

    # apply transformation
    tf = tfidf_vectorizer.fit_transform(X_train['tweet_clean'])
    
    # tf_feature_names tells us what word each column in the matric represents
    tf_feature_names = tfidf_vectorizer.get_feature_names()
    print(f"... tf_feature_names_nmf")
    # On sauvegarde les differents mots, commun à tous les modèles
    with open('models/tf_feature_names_nmf', 'w') as f:
        # create the csv writer
        writer = csv.writer(f)
        # write a row to the csv file
        writer.writerow(tf_feature_names)
        f.close()
    
    # Réalise le NMF modèle avec un nombre de topics allant de 2 à 10, puis on stocke les modèles 
    # 2 méthodes de NMF sont effectués: Frobenius, puis Kullback-Leibler
    if option == 'frobenius':
        for n_topics in range(2,11,1):
            model = NMF(n_components = n_topics, random_state = 0, alpha=.1, l1_ratio=.5)
            model.fit(tf)
            joblib.dump(model, f'models/NMF_Frobenius_{n_topics}_topics')
            print(f"... NMF_Frobenius_{n_topics}_topics")
    else:
        for n_topics in range(2,11,1):
            model = NMF(n_components= n_topics, random_state=0,
                        beta_loss='kullback-leibler', solver='mu', 
                        max_iter=1000, alpha=.1, l1_ratio=.5)
            model.fit(tf)
            joblib.dump(model, f'models/NMF_K-L_{n_topics}_topics')
            print(f"... NMF_K-L_{n_topics}_topics")

# %%
NMF_many_topics(option = 'frobenius')
NMF_many_topics(option = 'K-L')
# Out:
# ... tf_feature_names_nmf
# /Users/romain/.local/share/virtualenvs/Twitter_project-FHPMSXBU/lib/python3.8/site-packages/sklearn/decomposition/_nmf.py:312: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   warnings.warn(("The 'init' value, when 'init=None' and "
# ... NMF_Frobenius_2_topics
# /Users/romain/.local/share/virtualenvs/Twitter_project-FHPMSXBU/lib/python3.8/site-packages/sklearn/decomposition/_nmf.py:312: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   warnings.warn(("The 'init' value, when 'init=None' and "
# ... NMF_Frobenius_3_topics
# /Users/romain/.local/share/virtualenvs/Twitter_project-FHPMSXBU/lib/python3.8/site-packages/sklearn/decomposition/_nmf.py:312: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   warnings.warn(("The 'init' value, when 'init=None' and "
# /Users/romain/.local/share/virtualenvs/Twitter_project-FHPMSXBU/lib/python3.8/site-packages/sklearn/decomposition/_nmf.py:1090: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
# /Users/romain/.local/share/virtualenvs/Twitter_project-FHPMSXBU/lib/python3.8/site-packages/sklearn/decomposition/_nmf.py:312: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   warnings.warn(("The 'init' value, when 'init=None' and "
# ... NMF_Frobenius_4_topics
# ... NMF_Frobenius_5_topics
# /Users/romain/.local/share/virtualenvs/Twitter_project-FHPMSXBU/lib/python3.8/site-packages/sklearn/decomposition/_nmf.py:312: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   warnings.warn(("The 'init' value, when 'init=None' and "
# ... NMF_Frobenius_6_topics
# /Users/romain/.local/share/virtualenvs/Twitter_project-FHPMSXBU/lib/python3.8/site-packages/sklearn/decomposition/_nmf.py:312: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   warnings.warn(("The 'init' value, when 'init=None' and "
# ... NMF_Frobenius_7_topics
# /Users/romain/.local/share/virtualenvs/Twitter_project-FHPMSXBU/lib/python3.8/site-packages/sklearn/decomposition/_nmf.py:312: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   warnings.warn(("The 'init' value, when 'init=None' and "
# ... NMF_Frobenius_8_topics
# /Users/romain/.local/share/virtualenvs/Twitter_project-FHPMSXBU/lib/python3.8/site-packages/sklearn/decomposition/_nmf.py:312: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   warnings.warn(("The 'init' value, when 'init=None' and "
# ... NMF_Frobenius_9_topics
# /Users/romain/.local/share/virtualenvs/Twitter_project-FHPMSXBU/lib/python3.8/site-packages/sklearn/decomposition/_nmf.py:312: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   warnings.warn(("The 'init' value, when 'init=None' and "
# ... NMF_Frobenius_10_topics
# ... tf_feature_names_nmf
# /Users/romain/.local/share/virtualenvs/Twitter_project-FHPMSXBU/lib/python3.8/site-packages/sklearn/decomposition/_nmf.py:312: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   warnings.warn(("The 'init' value, when 'init=None' and "
# ... NMF_K-L_2_topics
# ... NMF_K-L_3_topics
# ... NMF_K-L_4_topics
# ... NMF_K-L_5_topics
# ... NMF_K-L_6_topics
# ... NMF_K-L_7_topics
# ... NMF_K-L_8_topics
# ... NMF_K-L_9_topics
# ... NMF_K-L_10_topics

# %%
with open('models/tf_feature_names_nmf', 'r') as file:
    tf_feature_names_nmf = list(csv.reader(file))

nmf10 = joblib.load('models/NMF_K-L_10_topics')

display_topics(nmf10, tf_feature_names_nmf[0], 10)
# Out:
#   Topic 0 words Topic 0 weights    Topic 1 words Topic 1 weights  \
# 0         clubs             1.9            perez             3.7
# 1         faire             0.7       florentino             2.4
# 2        projet             0.6        president             0.7
# 3          club             0.5             soir             0.5
# 4    supporters             0.5          agnelli             0.4
# 5       annonce             0.5           moment             0.4
# 6          gros             0.4     actuellement             0.4
# 7       veulent             0.4             real             0.3
# 8    fondateurs             0.3  florentinoperez             0.2
# 9   competition             0.3  elchiringuitotv             0.2
#
#          Topic 2 words Topic 2 weights Topic 3 words Topic 3 weights  \
# 0               league             3.8      football             3.6
# 1                super             3.6         sport             0.7
# 2             officiel             0.4          mort             0.7
# 3                   rt             0.4        argent             0.5
# 4                  fav             0.4          tuer             0.3
# 5                hymne             0.4      europeen             0.3
# 6  europeansuperleague             0.2         monde             0.3
# 7           europeenne             0.2           fin             0.3
# 8            champions             0.2        riches             0.3
# 9              chelsea             0.1         train             0.3
#
#   Topic 4 words Topic 4 weights Topic 5 words Topic 5 weights  \
# 0           psg             2.0          foot             2.4
# 1           ldc             1.8      histoire             0.6
# 2        bayern             0.7         merde             0.4
# 3        finale             0.6           bon             0.4
# 4         annee             0.5      vraiment             0.4
# 5        gagner             0.5       twitter             0.4
# 6            om             0.5          vrai             0.4
# 7        nasser             0.4        jamais             0.3
# 8         gagne             0.4          veut             0.3
# 9        inside             0.4        tweets             0.3
#
#      Topic 6 words Topic 6 weights            Topic 7 words Topic 7 weights  \
# 0             uefa             3.0           superleagueout             2.5
# 1             fifa             1.5  notoeuropeansuperleague             0.6
# 2             coup             0.6                   projet             0.5
# 3          reforme             0.4                  chelsea             0.5
# 4              ucl             0.4                     real             0.5
# 5  championsleague             0.4          notosuperleague             0.4
# 6           guerre             0.3                     city             0.4
# 7           passer             0.3               manchester             0.3
# 8               vs             0.2                   madrid             0.3
# 9         nouvelle             0.2                     dure             0.3
#
#   Topic 8 words Topic 8 weights Topic 9 words Topic 9 weights
# 0         ligue             2.2       joueurs             1.4
# 1         annee             1.6         monde             1.2
# 2     champions             1.6       arsenal             0.9
# 3   competition             0.4        equipe             0.7
# 4      nouvelle             0.3         jouer             0.7
# 5        matchs             0.3         coupe             0.6
# 6        europe             0.3        france             0.5
# 7   championnat             0.2          voir             0.4
# 8         coupe             0.2       benzema             0.4
# 9        fermee             0.2       equipes             0.4

# %%
def plot_top_words(model, feature_names, n_top_words, title):
    # Case when more than 5 topics
    if len(model.components_) > 5:
        fig, axes = plt.subplots(2, 5, figsize=(30, 15), sharex=True)
        axes = axes.flatten()
        for topic_idx, topic in enumerate(model.components_):
            top_features_ind = topic.argsort()[:-n_top_words - 1:-1]
            top_features = [feature_names[i] for i in top_features_ind]
            weights = topic[top_features_ind]
    
            ax = axes[topic_idx]
            ax.barh(top_features, weights, height=0.7)
            ax.set_title(f'Topic {topic_idx +1}',
                         fontdict={'fontsize': 30})
            ax.invert_yaxis()
            ax.tick_params(axis='both', which='major', labelsize=20)
            for i in 'top right left'.split():
                ax.spines[i].set_visible(False)
        
            fig.suptitle(title, fontsize=40)
    # Case when less or equal to 5 topics
    else:
        fig, axes = plt.subplots(1, len(model.components_), figsize=(15, 7), sharex=True)
        axes = axes.flatten()
        for topic_idx, topic in enumerate(model.components_):
            top_features_ind = topic.argsort()[:-n_top_words - 1:-1]
            top_features = [feature_names[i] for i in top_features_ind]
            weights = topic[top_features_ind]
    
            ax = axes[topic_idx]
            ax.barh(top_features, weights, height=0.7)
            ax.set_title(f'Topic {topic_idx +1}',
                         fontdict={'fontsize': 13})
            ax.invert_yaxis()
            ax.tick_params(axis='both', which='major', labelsize=12)
            for i in 'top right left'.split():
                ax.spines[i].set_visible(False)
        
            fig.suptitle(title, fontsize=20)
    

    plt.subplots_adjust(top=0.88, bottom=0.05, wspace=0.90, hspace=0.3)

    return fig

# %% [markdown]
# It shows the most relevant word for each topics

# %%
plot_top_words(nmf10, tf_feature_names_nmf[0], 8, 'rere')

# %% [markdown]
# #### K-Means

# %%
from sklearn.cluster import KMeans

tfidf_vectorizer = TfidfVectorizer(max_df=0.95, min_df=2,
                                   max_features=2000)

# apply transformation
tf = tfidf_vectorizer.fit_transform(tweets['tweet_clean'])
    
# tf_feature_names tells us what word each column in the matric represents
tf_feature_names = tfidf_vectorizer.get_feature_names()

num_clusters = 5
km = KMeans(n_clusters=num_clusters)

# %time km.fit(tf)

clusters = km.labels_.tolist()
# Out:
# CPU times: user 17 s, sys: 932 ms, total: 18 s
# Wall time: 2.65 s

# %%
di = { 'tweet_clean': tweets['tweet_clean'], 'cluster': clusters}

frame = pd.DataFrame(di )
frame
# Out:
#                                                   tweet_clean  cluster
# date
# 2021-04-21  jean michel incisif face frondeurs superleague...        0
# 2021-04-21  beppe marotta ad inter lance cri alarme faire ...        2
# 2021-04-21  echec projet superleague mort football visage ...        1
# 2021-04-21  jean michel heureux mort superleague etiennela...        0
# 2021-04-21  juve parme coupes uefa comprennent besoin supe...        0
# ...                                                       ...      ...
# 2021-04-18  arsenal fra comprends accepter vouloir tuer fo...        1
# 2021-04-18  dingue groupes supporters chelsea cst reagi cr...        0
# 2021-04-18  superleague clairement projet nefaste foot ref...        0
# 2021-04-18   ultras paris superleague club francais allema...        0
# 2021-04-18                       mascarade superleague penses        0
#
# [37349 rows x 2 columns]

# %%
frame['cluster'].value_counts()
# Out:
# 0    25054
# 2     4371
# 1     3297
# 4     2467
# 3     2160
# Name: cluster, dtype: int64

# %%
order_centroids = km.cluster_centers_.argsort()[:, ::-1] 
len(order_centroids[0])
# Out:
# 2000

# %%
for i in range(num_clusters):
    print("Cluster %d words:" % i, end='')
    
    for ind in order_centroids[i, :6]: #replace 6 with n words per cluster
        print(ind)
# Out:
# Cluster 0 words:747
# 1897
# 1005
# 1491
# 81
# 1794
# Cluster 1 words:748
# 1184
# 1897
# 107
# 1172
# 1769
# Cluster 2 words:298
# 1897
# 967
# 745
# 828
# 78
# Cluster 3 words:1347
# 736
# 1794
# 1443
# 1897
# 1548
# Cluster 4 words:1006
# 1792
# 264
# 1897
# 1026
# 298

# %%
from __future__ import print_function

print("Top terms per cluster:")
print()
#sort cluster centers by proximity to centroid
order_centroids = km.cluster_centers_.argsort()[:, ::-1] 

for i in range(num_clusters):
    print("Cluster %d words:" % i, end='')
    
    for ind in order_centroids[i, :6]: #replace 6 with n words per cluster
        print(' %s' % vocab_frame.ix[tf_feature_names[ind].split(' ')].values.tolist()[0][0].encode('utf-8', 'ignore'), end=',')
    print() #add whitespace
    print() #add whitespace
    
print()
print()
# Out:
# Top terms per cluster:
#
# Cluster 0 words:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-37-2a241ca8b1c7> in <module>
#      10
#      11     for ind in order_centroids[i, :6]: #replace 6 with n words per cluster
# ---> 12         print(' %s' % vocab_frame.ix[tf_feature_names[ind].split(' ')].values.tolist()[0][0].encode('utf-8', 'ignore'), end=',')
#      13     print() #add whitespace
#      14     print() #add whitespace
#
# NameError: name 'vocab_frame' is not defined

# %%
text_content = tweets['tweet_clean']
vector = TfidfVectorizer(stop_words = 'english')
tfidf = vector.fit_transform(text_content)
text_content.head()
# Out:
# date
# 2021-04-21    jean michel incisif face frondeurs superleague...
# 2021-04-21    beppe marotta ad inter lance cri alarme faire ...
# 2021-04-21    echec projet superleague mort football visage ...
# 2021-04-21    jean michel heureux mort superleague etiennela...
# 2021-04-21    juve parme coupes uefa comprennent besoin supe...
# Name: tweet_clean, dtype: object

# %%
from sklearn.cluster import MiniBatchKMeans

K = range(1,15)
SSE = []
for k in K:
    kmeans = MiniBatchKMeans(n_clusters = k,batch_size = 300)
    kmeans.fit(tfidf)
    SSE.append(kmeans.inertia_)
    
import matplotlib.pyplot as plt
plt.plot(K,SSE,'bx-')
plt.title('Elbow Method')
plt.xlabel('cluster numbers')
plt.show()

# %%
k = 6
kmeans = MiniBatchKMeans(n_clusters = k)
kmeans.fit(tfidf)
centers = kmeans.cluster_centers_.argsort()[:,::-1]
terms = vector.get_feature_names()

te = pd.DataFrame()
for i in range(0,k):
    word_list=[]
    for j in centers[i,:9]:
        word_list.append(terms[j])
        
    te[f'Topic {i}'] =  word_list
    
te
# Out:
#        Topic 0         Topic 1         Topic 2        Topic 3         Topic 4  \
# 0      joueurs     superleague          league     iaxcxsrygg           perez
# 1  superleague        football           super         suisse      florentino
# 2        clubs           clubs     superleague          super     superleague
# 3        jouer            foot       champions         league  superleagueout
# 4         uefa            uefa           ligue    championnat       president
# 5        monde             psg            uefa           uefa        football
# 6        coupe             ldc           clubs    superleague            uefa
# 7         euro  superleagueout        football            frt            real
# 8         fifa           annee  superleagueout  frsuperleague           clubs
#
#       Topic 5
# 0    salopard
# 1  remportera
# 2     traitre
# 3   salopards
# 4  magnifique
# 5        demi
# 6       final
# 7       grand
# 8       coupe

# %% [markdown]
# ## Sentiment Analysis

# %%
from vaderSentiment_fr.vaderSentiment import SentimentIntensityAnalyzer

SIA = SentimentIntensityAnalyzer()

#phrase = "Une phrase très cool à analyser"
#score = SIA.polarity_scores(phrase)
#score['compound']
# Out:
# /Users/romain/.local/share/virtualenvs/Twitter_project-FHPMSXBU/lib/python3.8/site-packages/fuzzywuzzy/fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')

# %%
polarity = []
for tweet in tweets['tweet_clean']:
    polarity.append(SIA.polarity_scores(tweet)['compound'])

# %%
tweets['polarity'] = polarity

tweets.sort_values(by = 'polarity')
# Out:
#                  date      time  \
# date
# 2021-04-19 2021-04-19  11:46:39
# 2021-04-19 2021-04-19  20:28:11
# 2021-04-20 2021-04-20  00:45:52
# 2021-04-18 2021-04-18  23:11:45
# 2021-04-19 2021-04-19  19:09:58
# ...               ...       ...
# 2021-04-19 2021-04-19  13:39:31
# 2021-04-19 2021-04-19  00:43:16
# 2021-04-21 2021-04-21  13:24:15
# 2021-04-21 2021-04-21  07:09:49
# 2021-04-20 2021-04-20  19:33:26
#
#                                                         tweet  \
# date
# 2021-04-19  Honte à toi Perez  Honte à toi Agnelli  Honte ...
# 2021-04-19  Anti UEFA X Anti Superleague  Des voleurs qui ...
# 2021-04-20  De quoi tu parles le vieux ?   Arsenal : A chi...
# 2021-04-18  425 millions en cas d’acceptation à intégrer l...
# 2021-04-19  #SuperLeague Bras de fer d'enculés.  D'un côté...
# ...                                                       ...
# 2021-04-19  #SuperLeague je suis pour,le concept de champi...
# 2021-04-19  La #SuperLeague est créée ↪️ Ses membres sont ...
# 2021-04-21  @acmilan : "Nous avons accepté l'invitation à ...
# 2021-04-21  Le football éthique est un mensonge. Le meille...
# 2021-04-20  3 anglais - champion + 2 meilleurs sur 5 saiso...
#
#                                                   tweet_clean  \
# date
# 2021-04-19  honte perez honte agnelli honte glazer honte a...
# 2021-04-19  anti uefa anti superleague voleurs vole rentre...
# 2021-04-20  parles vieux arsenal chier athletico chier tot...
# 2021-04-18  millions cas acceptation integrer superleague ...
# 2021-04-19  superleague bras fer encules cote encules uefa...
# ...                                                       ...
# 2021-04-19  superleague concept championnat interet clubs ...
# 2021-04-19  superleague creee membres bannis championnats ...
# 2021-04-21  acmilan accepte invitation participer projet s...
# 2021-04-21  football ethique mensonge meilleur spectacle m...
# 2021-04-20  anglais champion meilleurs saisons allemands c...
#
#                                                      hashtags  likes_count  \
# date
# 2021-04-19                                    ['superleague']           92
# 2021-04-19  ['superleague', 'boycottsuperleague', 'fuckuefa']            0
# 2021-04-20                                    ['superleague']            0
# 2021-04-18                                    ['superleague']           23
# 2021-04-19                                    ['superleague']            2
# ...                                                       ...          ...
# 2021-04-19                                    ['superleague']            1
# 2021-04-19                                    ['superleague']            1
# 2021-04-21                                    ['superleague']            0
# 2021-04-21                                    ['superleague']            0
